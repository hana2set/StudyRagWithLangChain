# %%
# !pip install unstructured
# Out:
# Collecting unstructured
#   Downloading unstructured-0.18.1-py3-none-any.whl.metadata (24 kB)
# Collecting chardet (from unstructured)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: filetype in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (1.2.0)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting nltk (from unstructured)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (4.13.4)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ------------------------------------- 981.5/981.5 kB 45.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (2.3.1)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (4.14.0)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.37.2-py3-none-any.whl.metadata (20 kB)
# Collecting wrapt (from unstructured)
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: tqdm in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured) (7.0.0)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from beautifulsoup4->unstructured) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from nltk->unstructured) (8.2.1)
# Requirement already satisfied: joblib in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from nltk->unstructured) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: colorama in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from requests->unstructured) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from requests->unstructured) (2025.6.15)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Downloading cryptography-45.0.4-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured-client->unstructured) (2.11.7)
# Requirement already satisfied: pypdf>=4.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured-client->unstructured) (5.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from cffi>=1.14->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: anyio in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Downloading unstructured-0.18.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 47.2 MB/s eta 0:00:00
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    --------------------------------------- 590.6/590.6 kB 21.9 MB/s eta 0:00:00
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 45.6 MB/s eta 0:00:00
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 29.1 MB/s eta 0:00:00
# Downloading unstructured_client-0.37.2-py3-none-any.whl (210 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading cryptography-45.0.4-cp311-abi3-win_amd64.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    ---------------------------------------- 3.4/3.4 MB 50.0 MB/s eta 0:00:00
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993363 sha256=d7dd547a8868b09368aa81362ca60bbe90d9d0c377452c64ba6870462e1fdecc
#   Stored in directory: c:\users\devuser\appdata\local\pip\cache\wheels\0a\f2\b2\e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: wrapt, rapidfuzz, python-magic, python-iso639, olefile, lxml, langdetect, html5lib, emoji, chardet, backoff, aiofiles, python-oxmsg, nltk, cryptography, unstructured-client, unstructured
#
#    -- -------------------------------------  1/17 [rapidfuzz]
#    ---- -----------------------------------  2/17 [python-magic]
#    ----------- ----------------------------  5/17 [lxml]
#    ----------- ----------------------------  5/17 [lxml]
#    -------------- -------------------------  6/17 [langdetect]
#    ---------------- -----------------------  7/17 [html5lib]
#    --------------------- ------------------  9/17 [chardet]
#    --------------------- ------------------  9/17 [chardet]
#    --------------------- ------------------  9/17 [chardet]
#    ---------------------------- ----------- 12/17 [python-oxmsg]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    ------------------------------ --------- 13/17 [nltk]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    ----------------------------------- ---- 15/17 [unstructured-client]
#    ----------------------------------- ---- 15/17 [unstructured-client]
#    ----------------------------------- ---- 15/17 [unstructured-client]
#    ----------------------------------- ---- 15/17 [unstructured-client]
#    ----------------------------------- ---- 15/17 [unstructured-client]
#    ------------------------------------- -- 16/17 [unstructured]
#    ------------------------------------- -- 16/17 [unstructured]
#    ------------------------------------- -- 16/17 [unstructured]
#    ------------------------------------- -- 16/17 [unstructured]
#    ------------------------------------- -- 16/17 [unstructured]
#    ------------------------------------- -- 16/17 [unstructured]
#    ------------------------------------- -- 16/17 [unstructured]
#    ---------------------------------------- 17/17 [unstructured]
#
# Successfully installed aiofiles-24.1.0 backoff-2.2.1 chardet-5.2.0 cryptography-45.0.4 emoji-2.14.1 html5lib-1.1 langdetect-1.0.9 lxml-5.4.0 nltk-3.9.1 olefile-0.47 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.13.0 unstructured-0.18.1 unstructured-client-0.37.2 wrapt-1.17.2
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-1.0.13-cp39-abi3-win_amd64.whl.metadata (7.1 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (2.11.7)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.1-cp311-cp311-win_amd64.whl.metadata (8.7 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (2.3.1)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (4.14.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (1.73.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp311-cp311-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.4)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.31.1)
# Requirement already satisfied: sympy in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-5.29.5-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Collecting distro>=1.5.0 (from posthog>=2.4.0->chromadb)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.0)
# Requirement already satisfied: filelock in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\devuser\anaconda3\envs\llm\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Using cached chromadb-1.0.13-cp39-abi3-win_amd64.whl (19.3 MB)
# Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.1.0-cp311-cp311-win_amd64.whl (41 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading onnxruntime-1.22.0-cp311-cp311-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    --------------- ------------------------ 5.0/12.7 MB 23.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.7 MB 30.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 28.4 MB/s eta 0:00:00
# Using cached opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.34.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
# Using cached opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
# Using cached protobuf-5.29.5-cp310-abi3-win_amd64.whl (434 kB)
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading pybase64-1.4.1-cp311-cp311-win_amd64.whl (36 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached uvicorn-0.34.3-py3-none-any.whl (62 kB)
# Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl (88 kB)
# Downloading watchfiles-1.1.0-cp311-cp311-win_amd64.whl (292 kB)
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=0291faa78083ef8b9f0bed393f0f7884e626b9e42e4b64076d2ec1e03b49c46e
#   Stored in directory: c:\users\devuser\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, websockets, shellingham, pyreadline3, pyproject_hooks, pybase64, protobuf, oauthlib, mmh3, mdurl, httptools, distro, bcrypt, watchfiles, uvicorn, requests-oauthlib, posthog, opentelemetry-proto, opentelemetry-api, markdown-it-py, humanfriendly, build, rich, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, kubernetes, coloredlogs, typer, opentelemetry-sdk, onnxruntime, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    - --------------------------------------  1/34 [flatbuffers]
#    --- ------------------------------------  3/34 [websockets]
#    --- ------------------------------------  3/34 [websockets]
#    ----- ----------------------------------  5/34 [pyreadline3]
#    -------- -------------------------------  7/34 [pybase64]
#   Attempting uninstall: protobuf
#    -------- -------------------------------  7/34 [pybase64]
#     Found existing installation: protobuf 6.31.1
#    -------- -------------------------------  7/34 [pybase64]
#     Uninstalling protobuf-6.31.1:
#    -------- -------------------------------  7/34 [pybase64]
#       Successfully uninstalled protobuf-6.31.1
#    -------- -------------------------------  7/34 [pybase64]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    --------- ------------------------------  8/34 [protobuf]
#    ---------- -----------------------------  9/34 [oauthlib]
#    ---------- -----------------------------  9/34 [oauthlib]
#    ------------ --------------------------- 11/34 [mdurl]
#    ------------------ --------------------- 16/34 [uvicorn]
#    ------------------ --------------------- 16/34 [uvicorn]
#    --------------------- ------------------ 18/34 [posthog]
#    --------------------- ------------------ 18/34 [posthog]
#    ----------------------- ---------------- 20/34 [opentelemetry-api]
#    ------------------------ --------------- 21/34 [markdown-it-py]
#    ------------------------ --------------- 21/34 [markdown-it-py]
#    ------------------------ --------------- 21/34 [markdown-it-py]
#    --------------------------- ------------ 23/34 [build]
#    ---------------------------- ----------- 24/34 [rich]
#    ---------------------------- ----------- 24/34 [rich]
#    ---------------------------- ----------- 24/34 [rich]
#    ------------------------ -------- 25/34 [opentelemetry-semantic-conventions]
#    ------------------------ -------- 25/34 [opentelemetry-semantic-conventions]
#    ------------------------ -------- 25/34 [opentelemetry-semantic-conventions]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    ------------------------------- -------- 27/34 [kubernetes]
#    -------------------------------- ------- 28/34 [coloredlogs]
#    ----------------------------------- ---- 30/34 [opentelemetry-sdk]
#    ----------------------------------- ---- 30/34 [opentelemetry-sdk]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    ------------------------------------ --- 31/34 [onnxruntime]
#    -------------------------------------- - 33/34 [chromadb]
#    -------------------------------------- - 33/34 [chromadb]
#    -------------------------------------- - 33/34 [chromadb]
#    -------------------------------------- - 33/34 [chromadb]
#    -------------------------------------- - 33/34 [chromadb]
#    -------------------------------------- - 33/34 [chromadb]
#    -------------------------------------- - 33/34 [chromadb]
#    ---------------------------------------- 34/34 [chromadb]
#
# Successfully installed bcrypt-4.3.0 build-1.2.2.post1 chromadb-1.0.13 coloredlogs-15.0.1 distro-1.9.0 durationpy-0.10 flatbuffers-25.2.10 httptools-0.6.4 humanfriendly-10.0 kubernetes-33.1.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.1.0 oauthlib-3.3.1 onnxruntime-1.22.0 opentelemetry-api-1.34.1 opentelemetry-exporter-otlp-proto-common-1.34.1 opentelemetry-exporter-otlp-proto-grpc-1.34.1 opentelemetry-proto-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 posthog-5.4.0 protobuf-5.29.5 pybase64-1.4.1 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rich-14.0.0 shellingham-1.5.4 typer-0.16.0 uvicorn-0.34.3 watchfiles-1.1.0 websockets-15.0.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\devUSER\anaconda3\envs\llm\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.73.0 requires protobuf<7.0.0,>=6.30.0, but you have protobuf 5.29.5 which is incompatible.

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (1.34.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Requirement already satisfied: colorama in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (0.1.20)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.26 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-openai) (0.2.28)
# Requirement already satisfied: openai<2.0.0,>=1.32.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-openai) (1.34.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (0.1.98)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (2.7.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-openai) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (4.66.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.4.28)
# Requirement already satisfied: requests>=2.26.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain-openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain-openai) (1.2.1)
# Requirement already satisfied: certifi in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.26->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-openai) (3.10.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.26->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.26->langchain-openai) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.1)
# Requirement already satisfied: colorama in c:\users\jyseo\anaconda3\envs\openai\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.32.0->langchain-openai) (0.4.6)

# %%
from langchain.document_loaders import TextLoader
documents = TextLoader("../data/AI.txt").load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 문서를 청크로 분할
def split_docs(documents,chunk_size=1000,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

# docs 변수에 분할 문서를 저장
docs = split_docs(documents)

print(docs)
# Out:
# [Document(metadata={'source': '../data/AI.txt'}, page_content='Artificial intelligence (AI) is the intelligence of machines or software, as opposed to the intelligence of humans or animals. It is a field of study in computer science that develops and studies intelligent machines. Such machines may be called AIs.\n\nAI technology is widely used throughout industry, government, and science. Some high-profile applications are: advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon, and Netflix), understanding human speech (such as Google Assistant, Siri, and Alexa), self-driving cars (e.g., Waymo), generative and creative tools (ChatGPT and AI art), and superhuman play and analysis in strategy games (such as chess and Go).[1]'), Document(metadata={'source': '../data/AI.txt'}, page_content='Alan Turing was the first person to carry out substantial research in the field that he called Machine Intelligence.[2] Artificial intelligence was founded as an academic discipline in 1956.[3] The field went through multiple cycles of optimism[4][5] followed by disappointment and loss of funding.[6][7] Funding and interest vastly increased after 2012 when deep learning surpassed all previous AI techniques,[8] and after 2017 with the transformer architecture.[9] This led to the AI spring of the 2020s, with companies, universities, and laboratories overwhelmingly based in the United States pioneering significant advances in artificial intelligence.[10]'), Document(metadata={'source': '../data/AI.txt'}, page_content="The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and support for robotics.[a] General intelligence (the ability to complete any task performable by a human) is among the field's long-term goals.[11]\n\nTo solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience and other fields.[12]")]

# %%
#OpenAI의 임베딩 모델 사용
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import os
os.environ["GOOGLE_API_KEY"] = ''
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-exp-03-07")

# Chromdb에 벡터 저장, 저장 장소는 d:/data
from langchain.vectorstores import Chroma
db = Chroma.from_documents(docs, embeddings, persist_directory="../data")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model_name = "gemini-2.0-flash"
llm = ChatGoogleGenerativeAI(
    model=model_name,
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
    # other params...
)

# Q&A 체인을 사용하여 쿼리에 대한 답변 얻기
from langchain.chains.question_answering import load_qa_chain
chain = load_qa_chain(llm, chain_type="stuff",verbose=True)

# 쿼리를 작성하고 유사성 검색을 수행하여 답변을 생성,따라서 txt에 있는 내용을 질의해야 합니다
query = "AI란?"
matching_docs = db.similarity_search(query)
answer =  chain.run(input_documents=matching_docs, question=query)
answer
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the user's question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# Alan Turing was the first person to carry out substantial research in the field that he called Machine Intelligence.[2] Artificial intelligence was founded as an academic discipline in 1956.[3] The field went through multiple cycles of optimism[4][5] followed by disappointment and loss of funding.[6][7] Funding and interest vastly increased after 2012 when deep learning surpassed all previous AI techniques,[8] and after 2017 with the transformer architecture.[9] This led to the AI spring of the 2020s, with companies, universities, and laboratories overwhelmingly based in the United States pioneering significant advances in artificial intelligence.[10]
#
# Artificial intelligence (AI) is the intelligence of machines or software, as opposed to the intelligence of humans or animals. It is a field of study in computer science that develops and studies intelligent machines. Such machines may be called AIs.
#
# AI technology is widely used throughout industry, government, and science. Some high-profile applications are: advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon, and Netflix), understanding human speech (such as Google Assistant, Siri, and Alexa), self-driving cars (e.g., Waymo), generative and creative tools (ChatGPT and AI art), and superhuman play and analysis in strategy games (such as chess and Go).[1]
#
# The various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and support for robotics.[a] General intelligence (the ability to complete any task performable by a human) is among the field's long-term goals.[11]
#
# To solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience and other fields.[12]
# Human: 최초로 AI를 작업한 사람?
#
# > Finished chain.
#
# > Finished chain.
# '앨런 튜링은 그가 기계 지능이라고 부르는 분야에서 실질적인 연구를 수행한 최초의 사람이었습니다.'
